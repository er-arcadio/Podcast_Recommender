# %% [markdown]
# # Topic Modeling Podcasts
#
# The plan is to discover the main topics that "This American Life" podcast is covering through their entire archive.

# %%
# import podcast vec -- vector representation of each podcast in wordEmbed space
import pickle


# Uploads the the podcasts as a vector
with open('Flask/podcast_vec.pkl', 'rb') as handle:
    podcast_vec = pickle.load(handle)
    
# Opens the podcast title to ID reference
with open('Flask/title_ids.pkl', 'rb') as handle:
    PODCAST_IDS = pickle.load(handle)

    
# Opens the pretrained Word Embedding
with open('Flask/w2v.pkl', 'rb') as handle:
    w2v = pickle.load(handle)

# %% [markdown]
# ## Cleaning and Preprocessing the Corpus

# %%
import re
import nltk
SPECIAL_CHARS = '[^A-Za-z0-9 ]+'

def preprocess(text):
    tokenized = [word for sent in [re.sub(SPECIAL_CHARS, '', element).split(' ') for
                                  element in nltk.sent_tokenize(text)] for word in sent]
    
    lowered = [word.lower() for word in tokenized]
    return ' '.join(lowered)

# %%
import pandas as pd

PODCASTS = 'uncleaned_podcasts.csv'
df_podcasts = pd.read_csv(PODCASTS)
df_podcasts.head()

df_podcasts.dropna(inplace=True)

podcast_texts = [preprocess(text) for text in df_podcasts['Body'].tolist()]

# %%
processed_df = pd.DataFrame.from_dict( {
                                            'Title': df_podcasts['Title'],
                                            'Body': podcast_texts
                                        })
processed_df.head()
# Out:
#                    Title                                               Body
# 0         New Beginnings  joe franklin im ready its ira glass here oh yo...
# 1        Small Scale Sin  ok three boys aged 13 15 and 16 all three chos...
# 2      Poultry Slam 1995  in danielles house ever since she was a girl w...
# 3              Vacations  the thing about hawaii is that before you go a...
# 4  Anger and Forgiveness   hi its ira glass recording this in 2006 and t...

# %% [markdown]
# ## Using TF-IDF and NMF to Topic Model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english', max_df=0.8, min_df=0.2)
doc_spars = vectorizer.fit_transform(podcast_texts)
terms = vectorizer.get_feature_names()

# %%
doc_term = pd.DataFrame(doc_spars.toarray(), columns=terms)
doc_term.head()
# Out:
#         100      1000        11        12        13        14        15  \
# 0  0.000000  0.078835  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.014265  0.000000  0.019628
# 2  0.000000  0.066487  0.035005  0.009552  0.013059  0.012682  0.017968
# 3  0.000000  0.000000  0.000000  0.011312  0.000000  0.000000  0.010640
# 4  0.029256  0.020080  0.000000  0.014424  0.078884  0.000000  0.013567
#
#          16   17        18  ...   written     wrote     yard  yelling  yellow  \
# 0  0.017998  0.0  0.000000  ...  0.000000  0.000000  0.00000      0.0     0.0
# 1  0.013264  0.0  0.026383  ...  0.021947  0.017517  0.00000      0.0     0.0
# 2  0.048573  0.0  0.024153  ...  0.040184  0.000000  0.01632      0.0     0.0
# 3  0.000000  0.0  0.014302  ...  0.000000  0.009496  0.00000      0.0     0.0
# 4  0.018337  0.0  0.018236  ...  0.000000  0.024216  0.00000      0.0     0.0
#
#    yesterday      york      youd     youll   younger
# 0   0.000000  0.025126  0.000000  0.000000  0.000000
# 1   0.016935  0.037036  0.009667  0.000000  0.000000
# 2   0.015503  0.016953  0.017700  0.018271  0.038641
# 3   0.000000  0.010039  0.010481  0.000000  0.000000
# 4   0.000000  0.025600  0.026729  0.000000  0.000000
#
# [5 rows x 1489 columns]

# %%
from sklearn.decomposition import NMF
comps = 9
nmf = NMF(n_components=comps)
doc_topic_arr = nmf.fit_transform(doc_spars)

index_ls = [f"component_{x+1}" for x in range(comps)]
topic_word = pd.DataFrame(nmf.components_.round(3),
             index = index_ls,
             columns = terms)
topic_word
# Out:
#                100   1000     11     12     13     14     15     16     17  \
# component_1  0.075  0.054  0.044  0.068  0.061  0.047  0.098  0.051  0.023
# component_2  0.095  0.059  0.036  0.049  0.025  0.024  0.059  0.024  0.018
# component_3  0.005  0.009  0.016  0.011  0.014  0.010  0.032  0.008  0.000
# component_4  0.029  0.000  0.043  0.063  0.033  0.031  0.029  0.038  0.035
# component_5  0.021  0.000  0.014  0.022  0.016  0.022  0.024  0.032  0.037
# component_6  0.014  0.020  0.025  0.024  0.018  0.033  0.031  0.008  0.036
# component_7  0.023  0.012  0.028  0.024  0.011  0.008  0.017  0.014  0.028
# component_8  0.012  0.020  0.031  0.014  0.000  0.008  0.020  0.016  0.000
# component_9  0.000  0.003  0.010  0.005  0.008  0.006  0.000  0.011  0.000
#
#                 18  ...  written  wrote   yard  yelling  yellow  yesterday  \
# component_1  0.047  ...    0.077  0.105  0.062    0.051   0.053      0.029
# component_2  0.037  ...    0.055  0.074  0.004    0.013   0.004      0.008
# component_3  0.014  ...    0.000  0.006  0.000    0.002   0.004      0.019
# component_4  0.035  ...    0.057  0.100  0.027    0.025   0.045      0.029
# component_5  0.020  ...    0.013  0.050  0.000    0.018   0.000      0.005
# component_6  0.021  ...    0.005  0.033  0.042    0.027   0.009      0.025
# component_7  0.008  ...    0.035  0.055  0.010    0.010   0.004      0.016
# component_8  0.008  ...    0.031  0.012  0.040    0.000   0.029      0.002
# component_9  0.000  ...    0.014  0.000  0.005    0.002   0.002      0.009
#
#               york   youd  youll  younger
# component_1  0.236  0.111  0.115    0.041
# component_2  0.107  0.046  0.046    0.000
# component_3  0.021  0.000  0.014    0.020
# component_4  0.030  0.049  0.036    0.081
# component_5  0.091  0.000  0.017    0.027
# component_6  0.012  0.017  0.015    0.008
# component_7  0.016  0.016  0.015    0.000
# component_8  0.018  0.017  0.025    0.023
# component_9  0.000  0.019  0.020    0.005
#
# [9 rows x 1489 columns]

# %%
def display_topics(model, feature_names, no_top_words, topic_names=None):
    for ix, topic in enumerate(model.components_):
        if not topic_names or not topic_names[ix]:
            print("\nTopic ", ix)
        else:
            print(f"\nTopic {ix+1}: '",topic_names[ix],"'")
        print(", ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
display_topics(nmf, terms, 20)
# Out:
# Topic  0
# music, play, girl, song, game, david, street, dog, singing, york, book, women, playing, water, movie, eyes, sex, city, laughter, stage
#
# Topic  1
# president, government, company, vote, campaign, state, bank, party, political, office, business, court, pay, mike, law, federal, million, politics, jobs, states
#
# Topic  2
# speaking, spanish, camp, government, ice, dad, david, united, families, workers, mom, states, english, village, son, lots, hello, language, women, video
#
# Topic  3
# dad, mom, father, mother, parents, children, brother, child, fathers, sister, baby, kid, son, dads, mothers, hospital, died, daughter, letter, marriage
#
# Topic  4
# students, schools, black, white, teachers, teacher, class, church, college, student, parents, education, race, south, state, kid, district, group, children, neighborhood
#
# Topic  5
# police, crime, cops, officers, officer, prison, court, gun, jail, law, department, trial, evidence, drug, shot, attorney, guns, cop, arrested, city
#
# Topic  6
# war, military, americans, army, killed, government, states, united, president, men, forces, kill, battle, study, sarah, died, history, america, fighting, foreign
#
# Topic  7
# chicken, eat, workers, food, standard, animals, episode, restaurant, animal, sister, personality, eating, paul, naked, sun, wild, george, box, dogs, test
#
# Topic  8
# christmas, church, jesus, tree, singing, gift, mother, faith, store, child, window, mom, baby, town, present, song, john, children, david, prison

# %% [markdown]
# Here we're just adding labels

# %%
topics = ["Music and Media", "Politics", "Immigration", "Family", "Schooling",
          "Crime&Policing", "War", "Food", "Religion"]


doc_topic = pd.DataFrame(doc_topic_arr.round(5))

# %% [markdown]
# ## KMeans Cluster to check for significance

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

n_groups = 11

podcast_titles = df_podcasts['Title']


#Scale
scaled_doc_top = MinMaxScaler().fit_transform(doc_topic)


# KMeans km
km = KMeans(n_clusters=n_groups, random_state=100)

km.fit(scaled_doc_top)


#clustering actual track names using km.labels_
cluster = defaultdict(list)

for idx, group in enumerate(km.labels_):
    try:
        cluster[group].append(podcast_titles[idx])
    except KeyError:
        pass


#Description of each Cluster using km.cluster_centers_
clust_description = {}

for idx, spread in enumerate(km.cluster_centers_):
    total = sum(spread)
    
    description = ''
    for i, part in enumerate(spread):
        if part:
            description += f"'{topics[i]}' {(100*(part/total)).round(2)}% - "

    clust_description[idx] = description
    
    
# Printing the tracks under each description
for idx in clust_description:
    print(clust_description[idx])
    print(cluster[idx])
    print('\n')
# Out:
# 'Music and Media' 3.77% - 'Politics' 1.29% - 'Immigration' 0.8% - 'Family' 1.47% - 'Schooling' 0.8% - 'Crime&Policing' 6.35% - 'War' 0.61% - 'Food' 81.0% - 'Religion' 3.9% -
# ['Poultry Slam 1995', 'Poultry Slam 1996', 'Poultry Slam 1997', 'Poultry Slam 1998', 'Poultry Slam 1999', 'Poultry Slam 2003', 'How to Rest in Peace', 'Who Do You Think You Are?', 'Back to Penn State']
#
#
# 'Music and Media' 41.04% - 'Politics' 8.26% - 'Immigration' 2.32% - 'Family' 30.79% - 'Schooling' 5.23% - 'Crime&Policing' 4.88% - 'War' 3.18% - 'Food' 1.86% - 'Religion' 2.44% -
# ['Vacations', 'Dawn', 'Detectives', 'Sissies', 'Business of Death', 'Defying Sickness', 'One of Us', 'Telephone', 'Escape the Box', 'Monogamy', 'I Enjoy Being A Girl, Sort Of', 'Scenes from A Transplant', 'Truth and Lies at Age Ten', 'Last Words', 'You Gonna Eat That?', 'Lockup', 'Valentine’s Day ’99', 'High Cost of Living', 'The Book That Changed Your Life', 'Family Business', 'Barbara', 'Bedside Diplomacy', 'Kids As Adults', 'Crush', 'Dolls', 'Birthdays, Anniversaries, and Milestones', 'Kid Logic (2001)', 'How to Win Friends and Influence People', 'House on Loon Lake', 'Special Ed', 'Didn’t Ask to Be Born', 'Ask An Expert', 'Give the People What They Want', 'Suckers', 'Home Movies', 'Time to Save the World', 'Say Anything', 'Allure of the Mean Friend', 'Like It or Not', 'Living Without', 'Apology', 'My Big Break', 'Remember Me', 'The Arms Trader', 'A Little Bit of Knowledge', 'In the Shadow of the City', 'Habeas Schmabeas', 'The Parrot and the Potbellied Pig', 'Unconditional Love', 'With Great Power', 'Habeas Schmabeas 2007', 'The Devil in Me', 'The Competition', 'Home Alone', 'Tough Room', 'The Audacity of Government', 'Social Engineering', 'Switched at Birth', 'Fear of Sleep', 'Poultry Slam 2008', 'Scenes From a Recession', 'This I Used to Believe', 'Origin Story', 'Rest Stop', "Someone Else's Money", '#1 Party School', '2010', 'Contents Unknown', 'Ten Years In', 'Americans in China', 'Hiding in Plain Sight', 'Back to School', 'Send a Message', 'Harper High School - Part Two', 'Stuck In The Middle', 'Tarred and Feathered', 'Death and Taxes', 'I Was So High', 'Call For Help', 'A Not-So-Simple Majority', 'Is This Working?', 'A Front', "Regrets, I've Had a Few", 'Wake Up Now', 'Batman', 'Lower 9 + 10', 'The Night In Question', 'Say Yes To Christmas', 'When the Beasts Come Marching In', 'Don’t Have to Live Like a Refugee', '20 Years Later', 'Vague and Confused', 'Ask a Grown-Up', 'I Am Not A Pirate', 'Fear and Loathing in Homer and Rockville', 'White Haze', 'Rom-Com', 'The Impossible Dream', 'My Effing First Amendment', 'Before the Next One', 'How I Read It', 'I’m on TV??', 'Here’s Looking at You, Kid', 'Save the Girl', 'We Come From Small Places', 'Alone Together', 'Fiasco!', 'One Last Thing Before I Go', 'Umbrellas Down', 'Made to Be Broken']
#
#
# 'Music and Media' 10.2% - 'Politics' 58.68% - 'Immigration' 4.07% - 'Family' 5.67% - 'Schooling' 8.03% - 'Crime&Policing' 5.03% - 'War' 6.03% - 'Food' 0.8% - 'Religion' 1.49% -
# ['Economy', 'Rich Guys', 'Republican Convention', 'Democratic Convention', 'Politics', 'Ghosts of Elections Past', 'Primary', 'Character Assassination', 'The Fix Is In', 'Two Nations, One President', '81 Words', 'Give It to Them', 'Secret Government', 'My Two Cents', 'Regime Change', 'The Annoying Gap Between Theory...and Practice', 'The Middle of Nowhere', 'Leaving the Fold', 'The Facts Don’t Matter', 'Big Tent', 'Swing Set', 'Go Ask Your Father', 'Reunited (And It Feels So Good)', 'Nice Work If You Can Get It', 'Poultry Slam 2007', 'The Ghost of Bobby Dunbar', 'Mistakes Were Made', 'Got You Pegged', 'Going Big', 'Another Frightening Show About the Economy', 'A Better Mousetrap 2008', 'Scenes From a Mall', 'The Inauguration Show', 'Somewhere Out There', 'Bad Bank', 'Wrong Side of History', 'Return To The Scene Of The Crime', 'Turncoat', 'The Watchmen', 'Pro Se', 'Fine Print', 'Frenemies', 'Return To The Giant Pool of Money', 'More Is Less', 'Save the Day', 'Held Hostage', 'Right to Remain Silent', 'Iraq After Us', 'This Party Sucks', 'Toxie', 'Comedians of Christmas Comedy Special', 'The Invention of Money', 'Tough Room 2011', 'Know When To Fold ‘Em', 'Fine Print 2011', 'This Week', 'How To Create a Job', 'The Psychopath Test', 'A House Divided', 'Game Changer', 'Nemeses', 'Mr. Daisey and the Apple Factory', 'Continental Breakup', 'Play the Part', 'What Kind of Country', 'Own Worst Enemy', 'Our Friend David', 'Getting Away With It', 'No Coincidence, No Story!', 'Hit the Road', 'Hot In My Backyard', "The One Thing You're Not Supposed To Do", 'This Call May Be Recorded... To Save Your Life', 'How I Got Into College', 'Superpowers', 'The Seven Things You’re Not Supposed to Talk About', 'Origin Story 2014', 'Wait—Do You Have The Map?', 'Not It!', 'Abdi and the Golden Ticket', 'Sinatra’s 100th Birthday', 'My Damn Mind', 'Choosing Wrong', 'My Undesirable Talent ', 'Seriously?', 'Will I Know Anyone at This Party? ', 'Master of Her Domain… Name', 'Didn’t We Solve This One?', 'The Revolution Starts At Noon', 'The Other Mr. President', 'The Beginning of Now', 'Chip in My Brain', 'The Walls', 'Unteachable Moment', 'The Not-So-Great Unknown', 'The Runaways', "But That's What Happened", 'Where There Is a Will', 'The Room of Requirement', 'Wartime Radio', 'The Long Fuse', 'Seeing Yourself In the Wild', 'Ten Sessions']
#
#
# 'Music and Media' 42.07% - 'Politics' 21.69% - 'Immigration' 4.71% - 'Family' 6.84% - 'Schooling' 5.12% - 'Crime&Policing' 7.25% - 'War' 7.68% - 'Food' 1.26% - 'Religion' 3.38% -
# ['Small Scale Sin', 'Anger and Forgiveness', 'Name Change / No Theme', 'Bob Dole', 'A Night at the Wiener Circle', 'Letters', 'The Job That Takes Over Your Life', 'Fire', 'One Thing', "Who's Canadian?", 'Tales from the Net', "Other People's Mail", 'Pray', 'How Bad Is Bad?', 'How to Take Money from Strangers', 'Pinned by History', 'Trail of Tears', 'Notes on Camp', 'Ladies and Germs', 'Windfall', 'Apocalypse', 'Do-Gooders', 'Advice', 'We Didn’t', 'Hoaxing Yourself', 'What Remains', 'Secret Life of Daytime', 'Mob Mentality', 'Americans In Paris', 'Memo to the People of the Future', 'Golden Calf', 'Hitler’s Yacht', 'Them', 'Faith', 'Recordings for Someone', 'Plan B', 'Office Politics', 'Naming Names', 'Devil on My Shoulder', 'I’m In Charge Now', 'Enemy Camp', 'Later That Same Day', 'Brother’s Keeper', 'What I Should’ve Said', 'Desperate Measures', 'Special Treatment', 'Fake Science', 'Put Your Heart In It', 'Enemy Camp ‘04', 'Know Your Enemy', 'Backed Into A Corner', 'Image Makers', 'Not What I Signed Up For', 'This Is Not My Beautiful House', 'Settling the Score', 'Strangers in a Strange Land', 'David and Goliath', 'Seemed Like A Good Idea at the Time', 'A Better Mousetrap', 'What’s In A Number? — 2006 Edition', 'Shouting Across the Divide', 'The Super', 'My Brilliant Plan', 'What I Learned from Television', 'Big Wide World', 'Who Can You Save?', 'Man vs. History', 'Break-Up', 'Matchmakers', 'Ruining It for the Rest of Us', 'Fall Guy', 'Infidelity', 'Long Shot', 'NUMMI', 'True Urban Legends ', 'The Bridge', 'First Contact', 'Million Dollar Idea', 'See No Evil', 'Middle School', 'Poultry Slam 2011', 'What I Did For Love', 'Take the Money and Run for Office', 'What Happened at Dos Erres', 'Blackjack', 'Switcheroo', 'Little War on the Prairie', 'Animal Sacrifice', 'Lights, Camera, Christmas!', 'Trends With Benefits', 'Dr. Gilmer and Mr. Hyde', 'House Rules', 'Thought That Counts', 'Good Guys', 'Day At The Beach', 'Is That What I Look Like?', '180 Degrees', 'Mind Your Own Business', 'Magic Words', 'Cops See It Differently, Part Two', 'The Incredible Rarity of Changing Your Mind', 'Too Soon?', 'Transformers', 'Anatomy of Doubt ', 'It’ll Make Sense When You’re Older', 'Mind Games 2016', 'Tell Me I’m Fat', 'Kid Logic 2016', 'Fermi’s Paradox', 'The Magic Show', 'Suitable for Children', 'In the Shadow of the City 2017', 'Expect Delays', 'Things I Mean to Know', 'Our Town - Part Two', 'The Secret of My Death', 'Crime Scene', 'The Theme That Shall Not Be Named', 'Scrambling to Get Off the Ice', 'Anything Can Be Anything', 'Left Behind', 'Escape From the Lab', "Everyone's a Critic", 'Nice White Parents']
#
#
# 'Music and Media' 14.89% - 'Politics' 7.72% - 'Immigration' 4.48% - 'Family' 57.29% - 'Schooling' 4.2% - 'Crime&Policing' 3.83% - 'War' 3.95% - 'Food' 1.18% - 'Religion' 2.47% -
# ['Julia Sweeney', 'Double Lives', 'Accidental Documentaries', 'Liars', 'Adult Children', "Father's Day '96", 'Valentine’s Day ‘97', 'Something for Nothing', 'Dream House', 'Haunted', 'Leave the Mask On', 'Father’s Day ‘98', 'Twentieth Century Man', 'Away From Home', 'Father’s Day ‘99', 'Where Words Fail', 'Mother’s Day', "Nobody's Family Is Going to Change", 'Babysitting', 'The Missing Parents Bureau', "Father's Day '01", 'Stories of Loss', 'Before It Had A Name', 'The Other Man', 'Family Physics', 'Come Back to Afghanistan', 'My Pen Pal', 'The Sanctity of Marriage', 'Miracle Cures', 'Someone to Watch Over Me', 'Family Legend', 'Best Interests', 'Should I Stay or Should I Go?', 'Not What I Meant', 'Godless America', 'What’s In A Number?', 'How We Talked Back Then', 'The Cat Came Back', 'The Center for Lessons Learned', 'Duty Calls', 'How to Talk to Kids', 'Ties That Bind', 'Return to Childhood', 'The Prosecutor', 'Life After Death', 'Enforcers', 'Ground Game', 'Stories Pitched by Our Parents', 'Kid Politics', 'Old Boys Network', "Father's Day 2011", 'What Doesn’t Kill You', 'Doppelgängers', 'No Place Like Home', 'Got Your Back', 'Good Guys 2015', 'The Land of Make Believe', 'Human Spectacle 2015', 'The Heart Wants What It Wants', 'For Your Reconsideration', 'In Defense of Ignorance', 'Becoming a Badger', 'Once More, With Feeling', 'Human Error in Volatile Situations', 'The Out Crowd', 'Too Close to Home', 'Low Hum of Menace']
#
#
# 'Music and Media' 8.97% - 'Politics' 7.15% - 'Immigration' 55.61% - 'Family' 9.17% - 'Schooling' 2.36% - 'Crime&Policing' 9.71% - 'War' 4.94% - 'Food' 1.16% - 'Religion' 0.94% -
# ['Hearts and Minds', 'Lost in Translation', 'Teenage Embed, Part Two', 'Island Time ', 'When Patents Attack!', 'Invisible Made Visible', 'When Patents Attack... Part Two!', '500!', 'The View From In Here', 'Fiasco!', 'The Radio Drama Episode ', 'Stuck In The Middle (2015)', 'Put a Bow on It', "Get Your Money's Worth", 'Are We There Yet?', 'Grand Gesture', 'OK, I’ll Do It', 'So a Monkey and a Horse Walk Into a Bar', 'Five Women', "It's My Party and I'll Try If I Want To", 'If You Build It, Will They Come?', 'Let Me Count the Ways', 'No Fair!', 'The Wannabes', 'Beer Summit', 'Small Things Considered', 'Digging Up the Bones\xa0', 'Get Back to Where You Once Belonged', 'Embiggening', 'Black Box', 'Stuck!']
#
#
# 'Music and Media' 13.43% - 'Politics' 8.58% - 'Immigration' 2.89% - 'Family' 8.41% - 'Schooling' 53.88% - 'Crime&Policing' 5.71% - 'War' 3.14% - 'Food' 1.03% - 'Religion' 2.92% -
# ['New Year', 'Factions', "Lincoln's Second Inaugural", 'Trek', 'Harold', 'Take A Negro Home', 'Welcome to America', 'The Real Thing', 'Election', 'Propriety', 'Two Steps Back', 'Sink or Swim', 'Valentine’s Day 2008', 'Middle of the Night', 'Inside Job', 'Adventure!', 'So Crazy It Just Might Work', 'Loopholes', 'Valentine’s Day', 'I Was Just Trying To Help', "It's Not the Product, It's the Person", 'The Alibi', 'Amateur Hour', 'Same Bed, Different Dreams', 'NUMMI (2015)', 'The Problem We All Live With - Part One', 'We Are in the Future', 'Private Geography', 'Essay B', 'Damned If You Do…', 'Random Acts of History', 'LaDonna', 'Change You Can Maybe Believe In', 'The Unhappy Deciders', 'Hoaxing Yourself', 'Abdi the American', 'How to Be Alone', 'Day at the Beach']
#
#
# 'Music and Media' 8.7% - 'Politics' 6.85% - 'Immigration' 3.92% - 'Family' 4.21% - 'Schooling' 2.22% - 'Crime&Policing' 7.77% - 'War' 65.35% - 'Food' 0.6% - 'Religion' 0.37% -
# ['Justice', 'War Stories', 'Rashomon', 'Why We Fight', 'The Real Story', 'The Balloon Goes Up', "I'm From the Private Sector and I'm Here to Help", 'In Country', 'Back from the Dead', 'Cat and Mouse', 'And the Call Was Coming from the Basement', 'My Reputation', 'The Ten Commandments', 'Crybabies', "Oh You Shouldn't Have", 'Gossip', 'Red State Blue State', 'Just What I Wanted']
#
#
# 'Music and Media' 68.54% - 'Politics' 5.36% - 'Immigration' 2.77% - 'Family' 6.9% - 'Schooling' 4.73% - 'Crime&Policing' 5.15% - 'War' 2.88% - 'Food' 1.63% - 'Religion' 2.03% -
# ['New Beginnings', 'Quitting', 'Enemies', 'Animals', 'Love', 'From A Distance', 'Drama Bug', 'Teenaged Girls', 'Basketball', 'The Cruelty of Children', 'Obsession', 'When You Talk About Music', 'Fall Clearance Sale', 'Simulated Worlds', 'Halloween', 'Lessons', 'Get Over It!', 'Faustian Bargains', 'Media Fringe', 'Animals', 'Shoulda Been Dead', 'Animals Die, People Ponder', 'Edge of Sanity', 'Sinatra', 'Three Women and the Sex Industry', 'Name Change', 'Delivery', 'Small Towns', 'Fiasco!', 'Summer', 'Your Dream, My Nightmare', 'Blame It on Art', 'Conventions', 'Kindness of Strangers', 'Mob', 'Stuck in the Wrong Decade', 'Running After Antelope', 'Numbers', 'Sibling Rivalry', 'Valentine’s Day ’98 ', 'How To', 'Death to Wacky', 'Throwing the First Punch', 'Radio', 'Niagara', 'Road Trip!', 'Music Lessons', 'Mapping', 'Adventures in the Simple Life', 'First Day', 'What You Lookin’ At?', 'Be Careful Who You Pretend to Be', 'Pimp Anthropology', 'Four Corners', 'The Kids Are Alright', 'Sales', 'You Are Here', 'Invisible Worlds', 'Urban Nature', "A Teenager's Guide to God", 'In Dog We Trust', 'Million Bubbles', 'Moving', 'Crime Scene', 'Pursuit of Happiness', '24 Hours at the Golden Apple', 'Three Kinds of Deception', 'American Limbo', 'Superpowers', 'Return to Childhood', 'The Friendly Man', 'Cringe', 'Neighbors', 'Prom', 'Living the Dream', 'I Know What You Did This Summer', 'Meet the Pros', 'Before and After', 'Somewhere in the Arabian Sea', 'Act V', 'Testosterone', 'Fake I.D.', 'Classifieds', 'Middlemen', 'Reruns', 'You Are So Beautiful…To Me', 'Starting From Scratch', 'Lost in America', '20 Acts in 60 Minutes', 'MacGyver', 'What Is This Thing?', 'Garbage', 'Promised Land', 'My Experimental Phase', 'Spies Like Us', 'Auto Show', 'After the Flood', 'Getting and Spending', 'The This American Life Holiday Spectacular', 'Star-Crossed Love', 'Parental Guidance Suggested', "It's Never Over", 'Houses of Ill Repute', 'By Proxy', 'The Spokesman', 'Human Resources', 'The Truth Will Out', 'The New Boss', 'Arms Trader 2009', 'Bait and Switch', 'Social Contract', 'Petty Tyrant', 'Neighborhood Watch', 'Slow To React', 'Original Recipe', 'Thugs', 'Amusement Park', 'The Incredible Case of the P.I. Moms', 'Reap What You Sow', 'Mortal Vs. Venial', 'The Convert', 'Self-Improvement Kick ', 'Surrogates', 'Picture Show', 'Taking Names', 'Confessions', 'It Says So Right Here', 'Dead Men Tell No Tales', 'If You Don’t Have Anything Nice to Say, SAY IT IN ALL CAPS', 'Three Miles', 'Need To Know Basis', 'Birds & Bees', 'Game Face', 'The Problem We All Live With - Part Two', 'What’s Going On In There?', 'Status Update', 'Something Only I Can See', 'Who Do We Think We Are?', 'The Perils of Intimacy', 'Deep End of the Pool', 'One Last Thing Before I Go', 'The Sun Comes Up', 'It’s Working Out Very Nicely', 'Mr. Lie Detector', 'Who You Gonna Call?', "Words You Can't Say", 'In Dog We Trust', 'ICE Capades', 'The Feather Heist', 'Before Things Went to Hell', 'The Weight Of Words', 'Burn It Down', 'Gardens of Branching Paths', 'The Test', 'Our Pulitzer-Winning Episode', 'A Mess to Be Reckoned With']
#
#
# 'Music and Media' 11.57% - 'Politics' 16.75% - 'Immigration' 2.8% - 'Family' 9.32% - 'Schooling' 6.74% - 'Crime&Policing' 47.04% - 'War' 3.9% - 'Food' 0.62% - 'Religion' 1.25% -
# ['Guns', 'Allure of Crime', 'Sentencing', 'Can You Fight City Hall…If You Are City Hall?', 'Immigration', 'Cicero', 'Perfect Evidence', 'High Speed Chase', 'DIY', 'Quiz Show', 'The Giant Pool of Money', 'No Map', 'Parent Trap', 'Enemy Camp 2010', 'Georgia Rambler', 'Will They Know Me Back Home?', 'Very Tough Love', 'Living Without (2011)', 'Show Me the Way', 'Harper High School - Part One', 'Tribes', 'Use Only as Directed', 'Secret Identity', 'Except For That One Thing', 'Bad Baby', 'Human Spectacle', 'The Secret Recordings of Carmen Segarra', 'The Leap', 'Burroughs 101', 'Cops See It Differently, Part One', "Captain's Log", 'I Thought I Knew You', "That's One Way to Do It", 'My Summer Self', 'To Be Real', 'Our Town - Part One', 'I Thought It Would Be Easier', 'Beware the Jabberwock', 'Get a Spine!', 'The Show of Delights', 'Time Out', 'We Are in the Future', 'Here, Again', 'The Reprieve']
#
#
# 'Music and Media' 7.64% - 'Politics' 2.08% - 'Immigration' 1.43% - 'Family' 9.07% - 'Schooling' 0.7% - 'Crime&Policing' 1.41% - 'War' 0.31% - 'Food' 1.48% - 'Religion' 75.88% -
# ['Christmas', 'Christmas and Commerce', 'A Very Special Sedaris Christmas', 'The Angels Wanna Wear My Red Suit', 'This American Life’s Holiday Gift-Giving Guide', 'Heretics', 'Last Man Standing', 'This Week', '129 Cars', 'Poetry of Propaganda']

# %% [markdown]
# Conclusion
#
# - The clusters are distinct for the most part. Most clusters are a large majority, 1 topic.
# - However, this is not something I will include in my presentation as it has no place in a recommendation app.

# %% [markdown]
# ## Setting up a CSV file for a word cloud

# %%
corp_term = doc_term.sum(axis=0).reset_index()
total = corp_term[0].sum()

corp_term.sort_values(by=0, ascending=False, inplace=True, ignore_index=True)
corp_term.rename(columns={'index':'key', 0:'freq'}, inplace=True)
corp_term['freq'] = round(corp_term['freq']) - 12
corp_term['freq'] = corp_term['freq'].astype(int)
corp_term['word'] = corp_term['key']
corp_term.drop('key', axis=1, inplace=True)

# %%
word_cloud = corp_term.iloc[:100]

# %%
word_cloud.to_csv('word_cloud.csv', index=False, header=False)

# %%
# !cat word_cloud.csv
# Out:
# 20,dad
# 20,mom
# 19,mother
# 17,father
# 14,parents
# 14,speaking
# 13,police
# 12,black
# 12,white
# 10,city
# 10,war
# 9,book
# 9,government
# 9,music
# 8,state
# 8,david
# 8,girl
# 8,town
# 7,kid
# 7,street
# 7,president
# 7,children
# 7,york
# 6,men
# 6,play
# 6,women
# 6,office
# 6,brother
# 6,church
# 5,wife
# 5,john
# 5,group
# 4,party
# 4,change
# 4,spanish
# 4,business
# 4,girls
# 4,game
# 4,court
# 4,baby
# 3,care
# 3,tv
# 3,company
# 3,death
# 3,line
# 3,mr
# 3,sex
# 3,water
# 3,eyes
# 3,hospital
# 3,song
# 3,shed
# 3,america
# 3,son
# 3,walk
# 3,states
# 3,laughter
# 3,theyd
# 3,met
# 2,food
# 2,wrote
# 2,hey
# 2,died
# 2,word
# 2,law
# 2,looks
# 2,sister
# 2,christmas
# 2,class
# 2,questions
# 2,letter
# 2,news
# 2,middle
# 2,college
# 2,store
# 2,students
# 2,body
# 2,child
# 2,prison
# 2,boy
# 2,happy
# 2,bed
# 1,pay
# 1,bleep
# 1,singing
# 1,deal
# 1,playing
# 1,alex
# 1,mike
# 1,laughs
# 1,building
# 1,lost
# 1,movie
# 1,tells
# 1,past
# 1,dog
# 1,gay
# 1,running
# 1,meeting
# 1,apartment

# %% [markdown]
# ## Future works
#
# - Come back to the podcasts and scrape dates so that the data can be analyzed over time.

# %%
# # input date?
# for title in list(podcast_vec.keys())
#     p_id = PODCAST_IDS[title]
#     dashed_title = title.replace(' ', '-')
#     link = f'https://www.thisamericanlife.org/{p_id}/{dashed_title}}'
#     #scrape link for "<span class=date-display-single>" .text
